# %% [markdown]
# # Introduction

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4])

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x, y)

# %%
# 1st method

fig = plt.figure() #creates a figure
ax = fig. add_subplot() #adds some axes
plt.show()

# %%
# 2nd method

fig = plt.figure()
ax  = fig. add_axes([1,1,1,1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended)

fig, ax = plt.subplots()
ax.plot(x,y)

# %% [markdown]
# # Matplotlib example workflow

# %%
# importing and get it ready for plotting in jupyter

# %matplotlib inline
import matplotlib.pyplot as plt

# 1.prepare data
x = [1,2,3,4]
y = [11,22,33,44]

# 2. setup plot
fig, ax = plt.subplots(figsize= (8, 10)) # (width,height)

# 3. plot the data

ax.plot(x, y)

# customize plot
ax.set(title = 'Simple plot',
      xlabel = 'x-axis',
      ylabel = 'y-axis')

fig.savefig("images/sample-plot.png")

# %% [markdown]
# # making figure with numpy array
#
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
#create some data

x = np.linspace(0, 10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# plot the data and create a line plot
fig, ax = plt. subplots()
ax. plot(x, x**2)

# %%
# scatter plot
fig, ax= plt.subplots()
ax. scatter(x, np.exp(x));

# %%
# Another scatter

fig, ax  = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# Make a plot from dictionary

nut_butter_prices = {'Almond Butter': 10,
                    "Peanut Butter": 8,
                    "Cashew Butter": 12}

fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())

ax.set(title= 'Nut-Butter store',
      ylabel = "price($)");

# %%
fig, ax = plt.subplots()
ax. barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()))
ax.set(title = "Nut-Butter Store",
      xlabel= "Prices($)")
# Out:
# [Text(0.5, 1.0, 'Nut-Butter Store'), Text(0.5, 0, 'Prices($)')]

# %%
# Histogram: Make some data

x = np.random.randn(1000)
x[:10]
# Out:
# array([ 0.45463637, -1.53226994,  0.37658511,  0.8297564 ,  0.27456829,
#        -1.0603187 , -1.88150199,  0.87452657,  0.64893611, -0.54822367])

# %%
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Two Options For subplots

# %%
# Subplot option 1:
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2,
                                            ncols = 2,
                                             figsize = (10, 5))

ax1. plot(x, x/2);
ax2. scatter(np.random.random(10), np.random.random(10))
ax3. bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4. hist(np.random.randn(100))
# Out:
# (array([ 2.,  2.,  7., 14., 20., 23., 16., 11.,  3.,  2.]),
#  array([-2.50683457, -2.01648433, -1.52613409, -1.03578385, -0.54543361,
#         -0.05508337,  0.43526686,  0.9256171 ,  1.41596734,  1.90631758,
#          2.39666782]),
#  <BarContainer object of 10 artists>)

# %%
# Subplot option 2:

fig, ax = plt. subplots(nrows = 2,
                       ncols = 2,
                       figsize = (10, 5))
# Plot to each different index
ax[0, 0]. plot(x, x/2)
ax[0, 1]. scatter(np.random.random(10), np.random.random(10))
ax[1, 0]. bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax[1, 1]. hist(np.random.randn(100));

# %% [markdown]
# ## PLOTTING FROM PANDAS DATAFRAME

# %%
import pandas as pd

car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index = pd.date_range ("1/1/2022", periods = 1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors        Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")
car_sales
# Out:
# <ipython-input-26-1ffd461fad4f>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "")
#      Make Colour  Odometer (KM)  Doors     Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4   40000
# 1   Honda    Red          87899      4   50000
# 2  Toyota   Blue          32549      3   70000
# 3     BMW  Black          11179      5  220000
# 4  Nissan  White         213095      4   35000
# 5  Toyota  Green          99213      4   45000
# 6   Honda   Blue          45698      4   75000
# 7   Honda   Blue          54738      4   70000
# 8  Toyota  White          60000      4   62500
# 9  Nissan  White          31600      4   97000

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2022", periods = len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date
# 0  Toyota  White         150043      4   40000 2022-01-01
# 1   Honda    Red          87899      4   50000 2022-01-02
# 2  Toyota   Blue          32549      3   70000 2022-01-03
# 3     BMW  Black          11179      5  220000 2022-01-04
# 4  Nissan  White         213095      4   35000 2022-01-05
# 5  Toyota  Green          99213      4   45000 2022-01-06
# 6   Honda   Blue          45698      4   75000 2022-01-07
# 7   Honda   Blue          54738      4   70000 2022-01-08
# 8  Toyota  White          60000      4   62500 2022-01-09
# 9  Nissan  White          31600      4   97000 2022-01-10

# %%
car_sales["Total Sale"] = car_sales["Price"].cumsum()  # because the type is 'String'
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date  \
# 0  Toyota  White         150043      4   40000 2022-01-01
# 1   Honda    Red          87899      4   50000 2022-01-02
# 2  Toyota   Blue          32549      3   70000 2022-01-03
# 3     BMW  Black          11179      5  220000 2022-01-04
# 4  Nissan  White         213095      4   35000 2022-01-05
# 5  Toyota  Green          99213      4   45000 2022-01-06
# 6   Honda   Blue          45698      4   75000 2022-01-07
# 7   Honda   Blue          54738      4   70000 2022-01-08
# 8  Toyota  White          60000      4   62500 2022-01-09
# 9  Nissan  White          31600      4   97000 2022-01-10
#
#                                           Total Sale
# 0                                              40000
# 1                                         4000050000
# 2                                    400005000070000
# 3                              400005000070000220000
# 4                         40000500007000022000035000
# ...

# %%
car_sales["Total Sale"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date  Total Sale
# 0  Toyota  White         150043      4   40000 2022-01-01       40000
# 1   Honda    Red          87899      4   50000 2022-01-02       90000
# 2  Toyota   Blue          32549      3   70000 2022-01-03      160000
# 3     BMW  Black          11179      5  220000 2022-01-04      380000
# 4  Nissan  White         213095      4   35000 2022-01-05      415000
# 5  Toyota  Green          99213      4   45000 2022-01-06      460000
# 6   Honda   Blue          45698      4   75000 2022-01-07      535000
# 7   Honda   Blue          54738      4   70000 2022-01-08      605000
# 8  Toyota  White          60000      4   62500 2022-01-09      667500
# 9  Nissan  White          31600      4   97000 2022-01-10      764500

# %%
car_sales.plot(x = "Sale Date", y = "Total Sale")
car_sales;

# %%
#Reassign as int
car_sales["Price"] = car_sales["Price"].astype(int)
car_sales.plot(x = 'Odometer (KM)', y = "Price",kind = "scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Bar Graph

x = np.random.rand(10, 4)
x
# Out:
# array([[0.76614465, 0.4772619 , 0.43244899, 0.52891641],
#        [0.77785883, 0.32546356, 0.94976434, 0.74853004],
#        [0.49980075, 0.83416708, 0.71762477, 0.40694604],
#        [0.02817003, 0.68158913, 0.1781683 , 0.8006288 ],
#        [0.89940175, 0.28052668, 0.4540162 , 0.14801309],
#        [0.28035294, 0.13363463, 0.36666183, 0.65544147],
#        [0.85850926, 0.53684759, 0.16256059, 0.99477019],
#        [0.90870506, 0.91919936, 0.78342008, 0.62423099],
#        [0.85502357, 0.77299892, 0.5308298 , 0.92737665],
#        [0.69031824, 0.61967867, 0.64897481, 0.59983895]])

# %%
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.766145  0.477262  0.432449  0.528916
# 1  0.777859  0.325464  0.949764  0.748530
# 2  0.499801  0.834167  0.717625  0.406946
# 3  0.028170  0.681589  0.178168  0.800629
# 4  0.899402  0.280527  0.454016  0.148013
# 5  0.280353  0.133635  0.366662  0.655441
# 6  0.858509  0.536848  0.162561  0.994770
# 7  0.908705  0.919199  0.783420  0.624231
# 8  0.855024  0.772999  0.530830  0.927377
# 9  0.690318  0.619679  0.648975  0.599839

# %%
df. plot.bar();

# %%
# or
df. plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Sale Date  Total Sale
# 0  Toyota  White         150043      4   40000 2022-01-01       40000
# 1   Honda    Red          87899      4   50000 2022-01-02       90000
# 2  Toyota   Blue          32549      3   70000 2022-01-03      160000
# 3     BMW  Black          11179      5  220000 2022-01-04      380000
# 4  Nissan  White         213095      4   35000 2022-01-05      415000
# 5  Toyota  Green          99213      4   45000 2022-01-06      460000
# 6   Honda   Blue          45698      4   75000 2022-01-07      535000
# 7   Honda   Blue          54738      4   70000 2022-01-08      605000
# 8  Toyota  White          60000      4   62500 2022-01-09      667500
# 9  Nissan  White          31600      4   97000 2022-01-10      764500

# %%
car_sales.plot(x = 'Make', y = 'Odometer (KM)')
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
car_sales.plot(x ='Make', y = 'Odometer (KM)', kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Make'>

# %%
# Histograms

car_sales["Odometer (KM)"]. plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# or

car_sales["Odometer (KM)"]. plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# adding bins

car_sales["Odometer (KM)"]. plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
heart_disease = pd. read_csv("heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# create Histogram of 'age' coloumn

heart_disease["age"]. plot. hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# # Pyplot vs matplotlib oo method
# * When plotting something quickly , okay to use pyplot methods
# * When plotting something advanced, use the oo method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot method

over_50.plot(kind = "scatter",
            x = 'age',
            y = 'chol',
            c = 'target',
            figsize = (10, 6));

# %%
# oo method mixed with pyplot method

fig, ax = plt.subplots(figsize = (10, 6))
over_50. plot(kind = 'scatter',
             x = 'age',
             y = 'chol',
             c = 'target',
             ax = ax);

# %%
# oo method from scratch

fig, ax = plt. subplots(figsize = (10, 6))
scatter = ax. scatter(x = over_50["age"], 
                     y = over_50["chol"],
                     c = over_50["target"])
ax. set(title = 'Heart Diesease And Cholesterol Levels',
       xlabel = "Age",
       ylabel = "Cholesterol")
# Add legends
ax.legend(*scatter.legend_elements(), title = "Target");
ax.axhline(over_50["chol"].mean(), 
          linestyle = "--");

# %%
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                             ncols = 1,
                             figsize = (10, 10),
                              sharex = True)
scatter = ax0.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"])
ax0.set(title = 'Heart Diesease Age And Cholesterol Levels',
       ylabel = "Cholesterol")

ax0.legend(*scatter.legend_elements(), title = "Target")

ax0.axhline(y = over_50["chol"].mean(),
           linestyle = "--")

scattter = ax1.scatter(x = over_50["age"],
                      y = over_50["thalach"],
                      c = over_50["target"])
ax1.set(title = "Heart Diesease Age and Max Heart Rate Levels",
        xlabel = "Age",
        ylabel = "Max Heart Rate")

ax1.legend(*scatter.legend_elements(), title = "Target")

ax1.axhline(y = over_50["thalach"].mean(),
           linestyle = "--")

fig.suptitle("Heart Diesease Analysis", fontsize = 16, fontweight = "bold");

# %% [markdown]
# # Customizing Matplotlib plots and getting stylish

# %%
# see the different styles available

plt.style. available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style. use("seaborn-whitegrid")
car_sales["Price"].plot();

# %%
car_sales.plot(x = "Odometer (KM)", y = "Price", kind = "scatter")
# Out:
# <AxesSubplot:xlabel='Odometer (KM)', ylabel='Price'>

# %%
# Create some data

x  = np.random.randn(10,4)
x
# Out:
# array([[-1.02251966, -0.09168453, -0.72416756, -0.50932934],
#        [ 0.10157635, -0.02071897, -0.53378833,  1.23824921],
#        [-0.36874104, -1.02189712,  0.54867169, -0.59178449],
#        [-0.9411975 , -1.99045363,  0.30320715,  0.68463679],
#        [-0.05426987, -0.4133229 ,  0.77155434, -0.90588581],
#        [ 0.97389182, -0.12849729, -0.39153669, -1.00233261],
#        [-0.20880974, -0.83804334, -2.94841676, -0.40506754],
#        [-0.35610899,  1.08083638, -0.42845948, -0.58796571],
#        [ 1.93445597, -0.14251987,  1.46853703,  1.04415266],
#        [ 0.51265562,  1.70481709, -1.14600034,  0.23697607]])

# %%
df = pd.DataFrame(x, columns = ['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -1.022520 -0.091685 -0.724168 -0.509329
# 1  0.101576 -0.020719 -0.533788  1.238249
# 2 -0.368741 -1.021897  0.548672 -0.591784
# 3 -0.941197 -1.990454  0.303207  0.684637
# 4 -0.054270 -0.413323  0.771554 -0.905886
# 5  0.973892 -0.128497 -0.391537 -1.002333
# 6 -0.208810 -0.838043 -2.948417 -0.405068
# 7 -0.356109  1.080836 -0.428459 -0.587966
# 8  1.934456 -0.142520  1.468537  1.044153
# 9  0.512656  1.704817 -1.146000  0.236976

# %%
ax = df.plot(kind = "bar")
ax.set(title = "Random Number Bar Graph From DataFrame",
      xlabel = "Row Number",
      ylabel = "Random Number");

# %%
# Set the style
plt.style.use("seaborn-whitegrid")

# oo method from scratch

fig, ax = plt. subplots(figsize = (10, 6))
scatter = ax. scatter(x = over_50["age"], 
                     y = over_50["chol"],
                     c = over_50["target"],
                     cmap = "winter") #this changes the color scheme
ax. set(title = 'Heart Diesease And Cholesterol Levels',
       xlabel = "Age",
       ylabel = "Cholesterol")
# Add legends
ax.legend(*scatter.legend_elements(), title = "Target");
ax.axhline(over_50["chol"].mean(), 
          linestyle = "--");

# %%
fig, (ax0, ax1) = plt.subplots(nrows = 2,
                             ncols = 1,
                             figsize = (10, 10),
                              sharex = True)
scatter = ax0.scatter(x = over_50["age"],
                     y = over_50["chol"],
                     c = over_50["target"],
                     cmap = "winter")
ax0.set(title = 'Heart Diesease Age And Cholesterol Levels',
       ylabel = "Cholesterol")

# chnage the x axis limit
ax0.set_xlim([50, 80])

ax0.legend(*scatter.legend_elements(), title = "Target")

ax0.axhline(y = over_50["chol"].mean(),
           linestyle = "--")

scattter = ax1.scatter(x = over_50["age"],
                      y = over_50["thalach"],
                      c = over_50["target"],
                      cmap = "winter")

ax1. set_xlim([50, 80])
ax1. set_ylim([60, 200])
ax1.set(title = "Heart Diesease Age and Max Heart Rate Levels",
        xlabel = "Age",
        ylabel = "Max Heart Rate")

ax1.legend(*scatter.legend_elements(), title = "Target")

ax1.axhline(y = over_50["thalach"].mean(),
           linestyle = "--")

fig.suptitle("Heart Diesease Analysis", fontsize = 16, fontweight = "bold");
